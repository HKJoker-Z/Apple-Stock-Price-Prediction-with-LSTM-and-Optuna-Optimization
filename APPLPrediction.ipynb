# %%
import yfinance as yf
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import optuna
from optuna.visualization import plot_optimization_history
import plotly.graph_objects as go

# %%
# ======================
# 1. 数据获取与预处理
# ======================
def download_stock_data(ticker, start_date, end_date):
    """
    从Yahoo Finance下载股票数据
    参数：
    - ticker: 股票代码（如'AAPL'）
    - start_date/end_date: 日期字符串（'YYYY-MM-DD'）
    返回：
    - 包含OHLCV数据的DataFrame
    """
    data = yf.download(ticker, start=start_date, end=end_date)
    data = data[['Open', 'High', 'Low', 'Close', 'Volume']]  # 选择关键特征
    print(f"下载数据量：{len(data)}条")
    return data

# 下载示例数据（苹果公司股票）
raw_data = download_stock_data('AAPL', '2010-01-01', '2023-12-31')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 下载数据量：3522条

# %%
# ======================
# 2. 特征工程
# ======================
def add_technical_indicators(df):
    """添加技术指标特征"""
    # 计算简单技术指标
    df['MA5'] = df['Close'].rolling(window=5).mean()
    df['MA20'] = df['Close'].rolling(window=20).mean()
    df['RSI'] = 100 - (100 / (1 + df['Close'].diff(1).clip(lower=0).rolling(14).mean() 
                             / df['Close'].diff(1).clip(upper=0).abs().rolling(14).mean()))
    df = df.dropna()
    return df

processed_data = add_technical_indicators(raw_data)

# %%
processed_data.head()
# Out:
# Price           Open      High       Low     Close     Volume       MA5  \
# Ticker          AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 2010-02-01  5.795470  5.904830  5.763235  5.866569  749876400  6.024735
# 2010-02-02  5.902120  5.914472  5.825899  5.900613  698342400  5.964000
# 2010-02-03  5.879824  6.031362  5.857229  6.002139  615328000  5.911880
# 2010-02-04  5.926824  5.976232  5.771371  5.785832  757652000  5.868257
# 2010-02-05  5.803303  5.904830  5.749677  5.888561  850306800  5.888743
#
# Price           MA20        RSI
# Ticker
# Date
# 2010-02-01  6.238213  38.180105
# 2010-02-02  6.210873  40.705299
# 2010-02-03  6.188052  41.111452
# 2010-02-04  6.159552  37.621090
# 2010-02-05  6.136776  42.533102

# %%
# ======================
# 3. 数据标准化
# ======================
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(processed_data)

# %%
# ======================
# 4. 动态序列生成（核心改进点）
# ======================
def create_sequences(data, window_size, target_col=3):  # target_col=3对应Close列
    """
    生成LSTM所需的序列数据
    参数：
    - data: 标准化后的数据矩阵
    - window_size: 时间窗口长度
    - target_col: 目标列索引（收盘价）
    返回：
    - X: 输入序列 (samples, window_size, features)
    - y: 输出值 (samples,)
    """
    X, y = [], []
    for i in range(len(data)-window_size):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size, target_col])
    return np.array(X), np.array(y)

# %%
# ======================
# 5. Optuna优化目标函数
# ======================
def objective(trial):
    # 动态超参数定义
    window_size = trial.suggest_int('window_size', 10, 60, step=5)
    n_features = scaled_data.shape[1]
    
    # 生成动态序列
    X, y = create_sequences(scaled_data, window_size)
    
    # 数据集划分（每次试验独立划分）
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)
    
    # 模型构建
    model = tf.keras.Sequential()
    
    # LSTM层配置
    n_layers = trial.suggest_int('n_layers', 1, 3)
    for i in range(n_layers):
        return_sequences = (i < n_layers-1)  # 最后一层不返回序列
        model.add(LSTM(
            units=trial.suggest_categorical(f'units_layer_{i}', [64, 128, 256]),
            return_sequences=return_sequences,
            input_shape=(window_size, n_features) if i==0 else None
        ))
        model.add(Dropout(trial.suggest_float(f'dropout_{i}', 0.1, 0.5)))
    
    # 输出层
    model.add(Dense(1))
    
    # 编译配置
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-2, log=True)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss='mse',
        metrics=['mae']
    )
    
    # 训练配置
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 128])
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=100,
        batch_size=batch_size,
        verbose=0,
        callbacks=[
            tf.keras.callbacks.EarlyStopping(
                patience=10,
                restore_best_weights=True
            )
        ]
    )
    
    return history.history['val_loss'][-1]

# %%
# ======================
# 6. 执行超参数优化
# ======================
study = optuna.create_study(
    direction='minimize',
    sampler=optuna.samplers.TPESampler(),
    pruner=optuna.pruners.MedianPruner()
)
study.optimize(objective, n_trials=50, show_progress_bar=True)

# 输出最佳参数
print("最佳参数:")
for key, value in study.best_params.items():
    print(f"{key}: {value}")
print(f"最佳验证MSE: {study.best_value:.6f}")
# Out:
# [I 2025-02-06 21:20:09,345] A new study created in memory with name: no-name-09bd86e1-2910-4816-9fbb-63e505d744e3
#   0%|          | 0/50 [00:00<?, ?it/s]
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [I 2025-02-06 21:20:30,544] Trial 0 finished with value: 0.000501026923302561 and parameters: {'window_size': 50, 'n_layers': 1, 'units_layer_0': 64, 'dropout_0': 0.4121669798720007, 'learning_rate': 0.000623229327715508, 'batch_size': 64}. Best is trial 0 with value: 0.000501026923302561.
# [I 2025-02-06 21:20:52,842] Trial 1 finished with value: 0.0024769639130681753 and parameters: {'window_size': 25, 'n_layers': 3, 'units_layer_0': 256, 'dropout_0': 0.4053122235583695, 'units_layer_1': 64, 'dropout_1': 0.137096083597686, 'units_layer_2': 64, 'dropout_2': 0.1349475946850077, 'learning_rate': 3.063218348677036e-05, 'batch_size': 128}. Best is trial 0 with value: 0.000501026923302561.
# [I 2025-02-06 21:25:37,843] Trial 2 finished with value: 0.01954404078423977 and parameters: {'window_size': 55, 'n_layers': 3, 'units_layer_0': 256, 'dropout_0': 0.2695648977229521, 'units_layer_1': 128, 'dropout_1': 0.4725290486706535, 'units_layer_2': 256, 'dropout_2': 0.33487331455963226, 'learning_rate': 0.006015146523499675, 'batch_size': 32}. Best is trial 0 with value: 0.000501026923302561.
# [I 2025-02-06 21:27:26,665] Trial 3 finished with value: 0.0007850959082134068 and parameters: {'window_size': 15, 'n_layers': 3, 'units_layer_0': 256, 'dropout_0': 0.3197851528411084, 'units_layer_1': 256, 'dropout_1': 0.2710485739414456, 'units_layer_2': 128, 'dropout_2': 0.2968705549563264, 'learning_rate': 0.0004629131730469662, 'batch_size': 32}. Best is trial 0 with value: 0.000501026923302561.
# [I 2025-02-06 21:29:16,176] Trial 4 finished with value: 0.0024712919257581234 and parameters: {'window_size': 40, 'n_layers': 3, 'units_layer_0': 64, 'dropout_0': 0.33203563101673783, 'units_layer_1': 128, 'dropout_1': 0.34975757580035294, 'units_layer_2': 256, 'dropout_2': 0.21963391982482292, 'learning_rate': 0.0044500750661783765, 'batch_size': 32}. Best is trial 0 with value: 0.000501026923302561.
# [I 2025-02-06 21:29:40,621] Trial 5 finished with value: 0.007748330943286419 and parameters: {'window_size': 25, 'n_layers': 3, 'units_layer_0': 128, 'dropout_0': 0.307569272723847, 'units_layer_1': 64, 'dropout_1': 0.42472710432206545, 'units_layer_2': 128, 'dropout_2': 0.350661049613562, 'learning_rate': 0.008916286546377517, 'batch_size': 64}. Best is trial 0 with value: 0.000501026923302561.
# [I 2025-02-06 21:31:07,456] Trial 6 finished with value: 0.0035722162574529648 and parameters: {'window_size': 40, 'n_layers': 3, 'units_layer_0': 128, 'dropout_0': 0.17658861628389955, 'units_layer_1': 128, 'dropout_1': 0.1962894541085557, 'units_layer_2': 64, 'dropout_2': 0.4984729887972547, 'learning_rate': 0.00017908342480975776, 'batch_size': 64}. Best is trial 0 with value: 0.000501026923302561.
# [I 2025-02-06 21:32:17,849] Trial 7 finished with value: 0.0018124943599104881 and parameters: {'window_size': 60, 'n_layers': 2, 'units_layer_0': 64, 'dropout_0': 0.3715717946721394, 'units_layer_1': 64, 'dropout_1': 0.1055321098648534, 'learning_rate': 1.6809435417511018e-05, 'batch_size': 64}. Best is trial 0 with value: 0.000501026923302561.
# [I 2025-02-06 21:33:55,997] Trial 8 finished with value: 0.0007785192574374378 and parameters: {'window_size': 40, 'n_layers': 1, 'units_layer_0': 256, 'dropout_0': 0.44472632761300684, 'learning_rate': 1.951294788672275e-05, 'batch_size': 128}. Best is trial 0 with value: 0.000501026923302561.
# [I 2025-02-06 21:35:45,127] Trial 9 finished with value: 0.0016175600467249751 and parameters: {'window_size': 55, 'n_layers': 3, 'units_layer_0': 256, 'dropout_0': 0.3652457367395665, 'units_layer_1': 128, 'dropout_1': 0.15277336464112867, 'units_layer_2': 128, 'dropout_2': 0.10667799052364019, 'learning_rate': 0.00572133583880596, 'batch_size': 64}. Best is trial 0 with value: 0.000501026923302561.
# [I 2025-02-06 21:35:50,552] Trial 10 finished with value: 0.002912728814408183 and parameters: {'window_size': 50, 'n_layers': 1, 'units_layer_0': 64, 'dropout_0': 0.4825653043584342, 'learning_rate': 0.0010112536300681389, 'batch_size': 64}. Best is trial 0 with value: 0.000501026923302561.
# [I 2025-02-06 21:36:02,899] Trial 11 finished with value: 0.0017420088406652212 and parameters: {'window_size': 45, 'n_layers': 1, 'units_layer_0': 64, 'dropout_0': 0.4979043881602941, 'learning_rate': 6.89027633298256e-05, 'batch_size': 128}. Best is trial 0 with value: 0.000501026923302561.
# [I 2025-02-06 21:36:25,660] Trial 12 finished with value: 0.0007754904800094664 and parameters: {'window_size': 30, 'n_layers': 1, 'units_layer_0': 256, 'dropout_0': 0.4306530340448017, 'learning_rate': 0.0011840093713365025, 'batch_size': 128}. Best is trial 0 with value: 0.000501026923302561.
# [I 2025-02-06 21:37:40,973] Trial 13 finished with value: 0.0012970977695658803 and parameters: {'window_size': 30, 'n_layers': 2, 'units_layer_0': 64, 'dropout_0': 0.22643674559311125, 'units_layer_1': 256, 'dropout_1': 0.31773728444788596, 'learning_rate': 0.0013598368639446893, 'batch_size': 128}. Best is trial 0 with value: 0.000501026923302561.
# [I 2025-02-06 21:37:58,193] Trial 14 finished with value: 0.00043846797780133784 and parameters: {'window_size': 10, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.42383043692805705, 'learning_rate': 0.0017079897887590184, 'batch_size': 128}. Best is trial 14 with value: 0.00043846797780133784.
# [I 2025-02-06 21:38:27,757] Trial 15 finished with value: 0.0014382167719304562 and parameters: {'window_size': 10, 'n_layers': 2, 'units_layer_0': 128, 'dropout_0': 0.13533004696152576, 'units_layer_1': 256, 'dropout_1': 0.24136969817948428, 'learning_rate': 0.0002749771141110826, 'batch_size': 64}. Best is trial 14 with value: 0.00043846797780133784.
# [I 2025-02-06 21:38:43,580] Trial 16 finished with value: 0.0022707581520080566 and parameters: {'window_size': 20, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.39606271340706645, 'learning_rate': 0.0006272999769020705, 'batch_size': 128}. Best is trial 14 with value: 0.00043846797780133784.
# [I 2025-02-06 21:38:58,039] Trial 17 finished with value: 0.0003727455041371286 and parameters: {'window_size': 10, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.4524661621316277, 'learning_rate': 0.0025108167386248908, 'batch_size': 128}. Best is trial 17 with value: 0.0003727455041371286.
# [I 2025-02-06 21:39:14,869] Trial 18 finished with value: 0.0014921561814844608 and parameters: {'window_size': 10, 'n_layers': 2, 'units_layer_0': 128, 'dropout_0': 0.46159103165241616, 'units_layer_1': 256, 'dropout_1': 0.37710766669277346, 'learning_rate': 0.002464775829010895, 'batch_size': 128}. Best is trial 17 with value: 0.0003727455041371286.
# [I 2025-02-06 21:39:33,615] Trial 19 finished with value: 0.000524410221260041 and parameters: {'window_size': 15, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.2533718005834569, 'learning_rate': 0.0024526583232128475, 'batch_size': 128}. Best is trial 17 with value: 0.0003727455041371286.
# [I 2025-02-06 21:39:42,235] Trial 20 finished with value: 0.0038647695910185575 and parameters: {'window_size': 15, 'n_layers': 2, 'units_layer_0': 128, 'dropout_0': 0.45591938272341437, 'units_layer_1': 64, 'dropout_1': 0.4671023252835049, 'learning_rate': 0.0025956241191578975, 'batch_size': 128}. Best is trial 17 with value: 0.0003727455041371286.
# [I 2025-02-06 21:39:52,548] Trial 21 finished with value: 0.0008243225747719407 and parameters: {'window_size': 10, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.4157303886902193, 'learning_rate': 0.0001674199471603591, 'batch_size': 128}. Best is trial 17 with value: 0.0003727455041371286.
# [I 2025-02-06 21:40:01,789] Trial 22 finished with value: 0.0017422050004824996 and parameters: {'window_size': 25, 'n_layers': 1, 'units_layer_0': 64, 'dropout_0': 0.35120979504977035, 'learning_rate': 0.0006869158561241403, 'batch_size': 64}. Best is trial 17 with value: 0.0003727455041371286.
# [I 2025-02-06 21:40:25,194] Trial 23 finished with value: 0.0005278054159134626 and parameters: {'window_size': 20, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.4074819661066829, 'learning_rate': 0.0017688182441204677, 'batch_size': 32}. Best is trial 17 with value: 0.0003727455041371286.
# [I 2025-02-06 21:40:33,442] Trial 24 finished with value: 0.0009228128474205732 and parameters: {'window_size': 35, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.4713267139207467, 'learning_rate': 0.0003329320045134389, 'batch_size': 128}. Best is trial 17 with value: 0.0003727455041371286.
# [I 2025-02-06 21:41:16,895] Trial 25 finished with value: 0.0031749005429446697 and parameters: {'window_size': 50, 'n_layers': 2, 'units_layer_0': 64, 'dropout_0': 0.37650334268628305, 'units_layer_1': 128, 'dropout_1': 0.22905363500367848, 'learning_rate': 0.0035633079086013616, 'batch_size': 64}. Best is trial 17 with value: 0.0003727455041371286.
# [I 2025-02-06 21:41:33,283] Trial 26 finished with value: 0.0008325797389261425 and parameters: {'window_size': 20, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.4369316717462004, 'learning_rate': 0.0008247751108969232, 'batch_size': 128}. Best is trial 17 with value: 0.0003727455041371286.
# [I 2025-02-06 21:41:45,668] Trial 27 finished with value: 0.00238231522962451 and parameters: {'window_size': 35, 'n_layers': 1, 'units_layer_0': 64, 'dropout_0': 0.34110377438940587, 'learning_rate': 9.639024714864369e-05, 'batch_size': 128}. Best is trial 17 with value: 0.0003727455041371286.
# [I 2025-02-06 21:44:10,234] Trial 28 finished with value: 0.0023013772442936897 and parameters: {'window_size': 60, 'n_layers': 2, 'units_layer_0': 128, 'dropout_0': 0.4992207857455125, 'units_layer_1': 256, 'dropout_1': 0.39756332763532176, 'learning_rate': 0.0015814973657893082, 'batch_size': 32}. Best is trial 17 with value: 0.0003727455041371286.
# [I 2025-02-06 21:44:23,124] Trial 29 finished with value: 0.0005772917647846043 and parameters: {'window_size': 25, 'n_layers': 1, 'units_layer_0': 64, 'dropout_0': 0.3969420492099955, 'learning_rate': 0.0004168451456315333, 'batch_size': 64}. Best is trial 17 with value: 0.0003727455041371286.
# [I 2025-02-06 21:44:52,635] Trial 30 finished with value: 0.0007327987696044147 and parameters: {'window_size': 45, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.42719461940063747, 'learning_rate': 0.008587826009798826, 'batch_size': 128}. Best is trial 17 with value: 0.0003727455041371286.
# [I 2025-02-06 21:45:06,111] Trial 31 finished with value: 0.0005965569289401174 and parameters: {'window_size': 15, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.2630613741945369, 'learning_rate': 0.002647944009162839, 'batch_size': 128}. Best is trial 17 with value: 0.0003727455041371286.
# [I 2025-02-06 21:45:12,818] Trial 32 finished with value: 0.0004209098406136036 and parameters: {'window_size': 10, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.28044001873128094, 'learning_rate': 0.0020379094851700275, 'batch_size': 128}. Best is trial 17 with value: 0.0003727455041371286.
# [I 2025-02-06 21:45:17,064] Trial 33 finished with value: 0.0006204863893799484 and parameters: {'window_size': 10, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.2845627464813114, 'learning_rate': 0.004208748125894103, 'batch_size': 128}. Best is trial 17 with value: 0.0003727455041371286.
# [I 2025-02-06 21:45:45,329] Trial 34 finished with value: 0.00025053374702110887 and parameters: {'window_size': 15, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.21645761596992258, 'learning_rate': 0.0006933930405182873, 'batch_size': 32}. Best is trial 34 with value: 0.00025053374702110887.
# [I 2025-02-06 21:46:07,087] Trial 35 finished with value: 0.00027964109904132783 and parameters: {'window_size': 15, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.11289261246587351, 'learning_rate': 0.0017699721781522938, 'batch_size': 32}. Best is trial 34 with value: 0.00025053374702110887.
# [I 2025-02-06 21:46:17,667] Trial 36 finished with value: 0.0003631389990914613 and parameters: {'window_size': 15, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.10744782558729385, 'learning_rate': 0.0005220641037728645, 'batch_size': 32}. Best is trial 34 with value: 0.00025053374702110887.
# [I 2025-02-06 21:46:45,173] Trial 37 finished with value: 0.0006094719865359366 and parameters: {'window_size': 15, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.12136113054785667, 'learning_rate': 0.0004594451763952356, 'batch_size': 32}. Best is trial 34 with value: 0.00025053374702110887.
# [I 2025-02-06 21:47:14,880] Trial 38 finished with value: 0.00036121116136200726 and parameters: {'window_size': 20, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.16511189044386151, 'learning_rate': 0.00022286936180585684, 'batch_size': 32}. Best is trial 34 with value: 0.00025053374702110887.
# [I 2025-02-06 21:48:10,627] Trial 39 finished with value: 0.0034613346215337515 and parameters: {'window_size': 20, 'n_layers': 2, 'units_layer_0': 256, 'dropout_0': 0.16657928396329785, 'units_layer_1': 64, 'dropout_1': 0.30855831427274155, 'learning_rate': 0.00020760303198030723, 'batch_size': 32}. Best is trial 34 with value: 0.00025053374702110887.
# [I 2025-02-06 21:48:25,951] Trial 40 finished with value: 0.0007076830952428281 and parameters: {'window_size': 30, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.10302004932455568, 'learning_rate': 7.879463089347817e-05, 'batch_size': 32}. Best is trial 34 with value: 0.00025053374702110887.
# [I 2025-02-06 21:49:01,061] Trial 41 finished with value: 0.0006452765082940459 and parameters: {'window_size': 15, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.18293774394162482, 'learning_rate': 0.00012856107872313095, 'batch_size': 32}. Best is trial 34 with value: 0.00025053374702110887.
# [I 2025-02-06 21:49:22,272] Trial 42 finished with value: 0.00038829463301226497 and parameters: {'window_size': 20, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.15655513984050276, 'learning_rate': 0.0009210606402674542, 'batch_size': 32}. Best is trial 34 with value: 0.00025053374702110887.
# [I 2025-02-06 21:49:58,882] Trial 43 finished with value: 0.0003161488857585937 and parameters: {'window_size': 15, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.19774300890400004, 'learning_rate': 0.00027605043430272265, 'batch_size': 32}. Best is trial 34 with value: 0.00025053374702110887.
# [I 2025-02-06 21:50:14,196] Trial 44 finished with value: 0.0006312059122137725 and parameters: {'window_size': 15, 'n_layers': 1, 'units_layer_0': 128, 'dropout_0': 0.20832438904164435, 'learning_rate': 4.161056745675022e-05, 'batch_size': 32}. Best is trial 34 with value: 0.00025053374702110887.
# [I 2025-02-06 21:51:47,725] Trial 45 finished with value: 0.00028641524841077626 and parameters: {'window_size': 25, 'n_layers': 1, 'units_layer_0': 256, 'dropout_0': 0.1441580421926187, 'learning_rate': 0.00029462791827166183, 'batch_size': 32}. Best is trial 34 with value: 0.00025053374702110887.
# [I 2025-02-06 21:52:55,661] Trial 46 finished with value: 0.0003271873283665627 and parameters: {'window_size': 25, 'n_layers': 1, 'units_layer_0': 256, 'dropout_0': 0.14439019420488666, 'learning_rate': 0.0002853413120724333, 'batch_size': 32}. Best is trial 34 with value: 0.00025053374702110887.
# [I 2025-02-06 21:58:19,481] Trial 47 finished with value: 0.0006038929568603635 and parameters: {'window_size': 25, 'n_layers': 2, 'units_layer_0': 256, 'dropout_0': 0.20842121100121372, 'units_layer_1': 256, 'dropout_1': 0.4996958547564946, 'learning_rate': 0.00015111860794429189, 'batch_size': 32}. Best is trial 34 with value: 0.00025053374702110887.
# [I 2025-02-06 22:02:00,991] Trial 48 finished with value: 0.0008357265032827854 and parameters: {'window_size': 30, 'n_layers': 3, 'units_layer_0': 256, 'dropout_0': 0.1392626040994642, 'units_layer_1': 64, 'dropout_1': 0.21156375832243085, 'units_layer_2': 64, 'dropout_2': 0.4782673453027476, 'learning_rate': 0.0003270558485670058, 'batch_size': 32}. Best is trial 34 with value: 0.00025053374702110887.
# [I 2025-02-06 22:03:50,989] Trial 49 finished with value: 0.0005283231730572879 and parameters: {'window_size': 25, 'n_layers': 1, 'units_layer_0': 256, 'dropout_0': 0.19890875785203083, 'learning_rate': 0.0002706834335470403, 'batch_size': 32}. Best is trial 34 with value: 0.00025053374702110887.
# 最佳参数:
# window_size: 15
# n_layers: 1
# units_layer_0: 128
# dropout_0: 0.21645761596992258
# learning_rate: 0.0006933930405182873
# batch_size: 32
# 最佳验证MSE: 0.000251

# %%
# ======================
# 7. 使用最佳参数训练最终模型
# ======================
# 获取最佳参数
best_window = study.best_params['window_size']
X_full, y_full = create_sequences(scaled_data, best_window)

# 划分最终数据集
X_train_final, X_test_final, y_train_final, y_test_final = train_test_split(
    X_full, y_full, test_size=0.2, shuffle=False
)

# %%
# 构建最终模型
final_model = tf.keras.Sequential()
for i in range(study.best_params['n_layers']):
    return_sequences = (i < study.best_params['n_layers']-1)
    final_model.add(LSTM(
        units=study.best_params[f'units_layer_{i}'],
        return_sequences=return_sequences,
        input_shape=(best_window, X_full.shape[2])
    ))
    final_model.add(Dropout(study.best_params[f'dropout_{i}']))
final_model.add(Dense(1))

final_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=study.best_params['learning_rate']),
    loss='mse'
)

# %%
# 训练最终模型
history = final_model.fit(
    X_train_final, y_train_final,
    epochs=200,
    batch_size=study.best_params['batch_size'],
    validation_data=(X_test_final, y_test_final),
    callbacks=[
        tf.keras.callbacks.EarlyStopping(patience=20)
    ]
)
# Out:
# Epoch 1/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0074 - val_loss: 0.0024
# Epoch 2/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0966e-04 - val_loss: 0.0041
# Epoch 3/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8436e-04 - val_loss: 6.3363e-04
# Epoch 4/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0969e-04 - val_loss: 0.0022
# Epoch 5/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5050e-04 - val_loss: 6.1080e-04
# Epoch 6/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0602e-04 - val_loss: 0.0033
# Epoch 7/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7611e-04 - val_loss: 0.0024
# Epoch 8/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4310e-04 - val_loss: 6.2595e-04
# Epoch 9/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5003e-04 - val_loss: 0.0018
# Epoch 10/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1418e-04 - val_loss: 6.2337e-04
# Epoch 11/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8565e-04 - val_loss: 4.6325e-04
# Epoch 12/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0822e-04 - val_loss: 0.0025
# Epoch 13/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4536e-04 - val_loss: 0.0017
# Epoch 14/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3746e-04 - val_loss: 8.5472e-04
# Epoch 15/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0682e-04 - val_loss: 7.0042e-04
# Epoch 16/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8140e-04 - val_loss: 7.8352e-04
# Epoch 17/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7509e-04 - val_loss: 9.3118e-04
# Epoch 18/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7351e-04 - val_loss: 5.7882e-04
# Epoch 19/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4542e-04 - val_loss: 4.5416e-04
# Epoch 20/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7172e-04 - val_loss: 4.2387e-04
# Epoch 21/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8436e-04 - val_loss: 8.7341e-04
# Epoch 22/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8122e-04 - val_loss: 0.0010
# Epoch 23/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5988e-04 - val_loss: 5.3014e-04
# Epoch 24/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7725e-04 - val_loss: 7.5006e-04
# Epoch 25/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3562e-04 - val_loss: 3.3350e-04
# Epoch 26/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9126e-04 - val_loss: 3.4349e-04
# Epoch 27/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5858e-04 - val_loss: 5.7012e-04
# Epoch 28/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4014e-04 - val_loss: 3.3045e-04
# Epoch 29/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3636e-04 - val_loss: 5.9991e-04
# Epoch 30/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4351e-04 - val_loss: 3.2748e-04
# Epoch 31/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3159e-04 - val_loss: 0.0026
# Epoch 32/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4184e-04 - val_loss: 7.2907e-04
# Epoch 33/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5567e-04 - val_loss: 6.9836e-04
# Epoch 34/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6772e-04 - val_loss: 3.3782e-04
# Epoch 35/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3061e-04 - val_loss: 4.1624e-04
# Epoch 36/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2744e-04 - val_loss: 8.5783e-04
# Epoch 37/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4493e-04 - val_loss: 3.4543e-04
# Epoch 38/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3286e-04 - val_loss: 4.2817e-04
# Epoch 39/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4024e-04 - val_loss: 3.0988e-04
# Epoch 40/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0304e-04 - val_loss: 6.2799e-04
# Epoch 41/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4815e-04 - val_loss: 4.2741e-04
# Epoch 42/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2136e-04 - val_loss: 3.3608e-04
# Epoch 43/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8255e-05 - val_loss: 2.7830e-04
# Epoch 44/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0632e-04 - val_loss: 6.2713e-04
# Epoch 45/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0961e-04 - val_loss: 0.0014
# Epoch 46/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2687e-04 - val_loss: 4.5020e-04
# Epoch 47/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7837e-05 - val_loss: 2.8722e-04
# Epoch 48/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1352e-04 - val_loss: 2.8839e-04
# Epoch 49/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8488e-05 - val_loss: 2.6820e-04
# Epoch 50/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3833e-04 - val_loss: 4.7712e-04
# Epoch 51/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1622e-04 - val_loss: 4.8698e-04
# Epoch 52/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3090e-04 - val_loss: 2.6213e-04
# Epoch 53/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3269e-04 - val_loss: 2.7797e-04
# Epoch 54/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2207e-04 - val_loss: 5.0812e-04
# Epoch 55/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4401e-05 - val_loss: 2.6348e-04
# Epoch 56/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0644e-04 - val_loss: 2.7640e-04
# Epoch 57/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3167e-04 - val_loss: 2.6556e-04
# Epoch 58/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1990e-04 - val_loss: 2.8552e-04
# Epoch 59/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1538e-04 - val_loss: 2.5963e-04
# Epoch 60/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2962e-04 - val_loss: 2.6074e-04
# Epoch 61/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1102e-04 - val_loss: 3.0036e-04
# Epoch 62/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4541e-04 - val_loss: 0.0021
# Epoch 63/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2845e-04 - val_loss: 4.3572e-04
# Epoch 64/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6591e-05 - val_loss: 3.8989e-04
# Epoch 65/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5968e-05 - val_loss: 3.8758e-04
# Epoch 66/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0621e-04 - val_loss: 3.1107e-04
# Epoch 67/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7328e-04 - val_loss: 2.6728e-04
# Epoch 68/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3293e-04 - val_loss: 0.0011
# Epoch 69/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2256e-04 - val_loss: 2.6001e-04
# Epoch 70/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0889e-04 - val_loss: 2.5004e-04
# Epoch 71/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1123e-04 - val_loss: 0.0024
# Epoch 72/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2801e-04 - val_loss: 3.5478e-04
# Epoch 73/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0197e-04 - val_loss: 2.6918e-04
# Epoch 74/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1588e-04 - val_loss: 3.4792e-04
# Epoch 75/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7372e-05 - val_loss: 6.7257e-04
# Epoch 76/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4221e-05 - val_loss: 4.9462e-04
# Epoch 77/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0774e-04 - val_loss: 6.9203e-04
# Epoch 78/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0867e-04 - val_loss: 2.7949e-04
# Epoch 79/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3686e-05 - val_loss: 3.7974e-04
# Epoch 80/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9700e-05 - val_loss: 3.8232e-04
# Epoch 81/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0180e-04 - val_loss: 2.5450e-04
# Epoch 82/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8386e-05 - val_loss: 2.4789e-04
# Epoch 83/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0213e-04 - val_loss: 2.4879e-04
# Epoch 84/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0255e-04 - val_loss: 2.4332e-04
# Epoch 85/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0289e-04 - val_loss: 2.5450e-04
# Epoch 86/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1233e-04 - val_loss: 2.3763e-04
# Epoch 87/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0821e-04 - val_loss: 2.4143e-04
# Epoch 88/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1979e-04 - val_loss: 4.4152e-04
# Epoch 89/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3086e-05 - val_loss: 2.7652e-04
# Epoch 90/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7779e-05 - val_loss: 2.5481e-04
# Epoch 91/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4216e-05 - val_loss: 3.3300e-04
# Epoch 92/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.1880e-05 - val_loss: 6.1331e-04
# Epoch 93/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1736e-04 - val_loss: 5.6582e-04
# Epoch 94/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7812e-05 - val_loss: 4.1516e-04
# Epoch 95/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.9298e-05 - val_loss: 8.8265e-04
# Epoch 96/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0446e-04 - val_loss: 2.4882e-04
# Epoch 97/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0050e-04 - val_loss: 2.4717e-04
# Epoch 98/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4626e-05 - val_loss: 4.4194e-04
# Epoch 99/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0546e-04 - val_loss: 2.6321e-04
# Epoch 100/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2626e-04 - val_loss: 2.3424e-04
# Epoch 101/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3432e-05 - val_loss: 4.4035e-04
# Epoch 102/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1178e-04 - val_loss: 2.5911e-04
# Epoch 103/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.8051e-05 - val_loss: 2.5803e-04
# Epoch 104/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0031e-04 - val_loss: 2.7642e-04
# Epoch 105/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.9637e-05 - val_loss: 2.6893e-04
# Epoch 106/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3056e-05 - val_loss: 6.3701e-04
# Epoch 107/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8576e-05 - val_loss: 3.4796e-04
# Epoch 108/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.8727e-05 - val_loss: 0.0010
# Epoch 109/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0766e-04 - val_loss: 2.5828e-04
# Epoch 110/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6593e-05 - val_loss: 2.3842e-04
# Epoch 111/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4942e-05 - val_loss: 4.3046e-04
# Epoch 112/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1170e-04 - val_loss: 8.8394e-04
# Epoch 113/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9568e-05 - val_loss: 4.1531e-04
# Epoch 114/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8434e-05 - val_loss: 6.4022e-04
# Epoch 115/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.9078e-05 - val_loss: 2.3414e-04
# Epoch 116/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.0690e-05 - val_loss: 3.1628e-04
# Epoch 117/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2699e-05 - val_loss: 6.5548e-04
# Epoch 118/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0861e-04 - val_loss: 5.3693e-04
# Epoch 119/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9183e-05 - val_loss: 2.5625e-04
# Epoch 120/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2406e-05 - val_loss: 4.5501e-04
# Epoch 121/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8374e-05 - val_loss: 6.9885e-04
# Epoch 122/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4137e-05 - val_loss: 2.5062e-04
# Epoch 123/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0253e-04 - val_loss: 9.6197e-04
# Epoch 124/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9665e-05 - val_loss: 5.0783e-04
# Epoch 125/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0706e-04 - val_loss: 9.2368e-04
# Epoch 126/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1618e-05 - val_loss: 6.7872e-04
# Epoch 127/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.5175e-05 - val_loss: 4.3945e-04
# Epoch 128/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7916e-05 - val_loss: 4.4734e-04
# Epoch 129/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.5081e-05 - val_loss: 2.5225e-04
# Epoch 130/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0394e-04 - val_loss: 0.0015
# Epoch 131/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7836e-05 - val_loss: 2.4680e-04
# Epoch 132/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8697e-05 - val_loss: 0.0010
# Epoch 133/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0578e-05 - val_loss: 0.0019
# Epoch 134/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7506e-05 - val_loss: 7.2897e-04
# Epoch 135/200
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.3066e-05 - val_loss: 2.5646e-04

# %%
# ======================
# 8. 结果可视化
# ======================
# 预测测试集
predictions = final_model.predict(X_test_final)
test_predictions = predictions.flatten()
# 反标准化
def inverse_scale_predictions(scaler, data, target_col=3):
    """
    专用反标准化函数（针对单列预测值）
    参数：
    - scaler: 已训练的MinMaxScaler对象
    - data: 预测值数组 (n_samples,)
    - target_col: 目标列在原始数据中的索引
    返回：
    - 反标准化后的目标列值 (n_samples,)
    """
    dummy = np.zeros((len(data), scaler.n_features_in_))
    dummy[:, target_col] = data
    return scaler.inverse_transform(dummy)[:, target_col]
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# 反标准化预测值
test_predictions_inv = inverse_scale_predictions(scaler, test_predictions)

# 反标准化真实值
true_values_inv = inverse_scale_predictions(scaler, y_test_final)

# --- 可视化修正 ---
# 生成日期索引（确保长度匹配）
last_dates = processed_data.index[-len(true_values_inv):]

fig = go.Figure()
fig.add_trace(go.Scatter(
    x=last_dates,
    y=true_values_inv,
    mode='lines',
    name='实际值',
    line=dict(color='#1f77b4')
))
fig.add_trace(go.Scatter(
    x=last_dates,
    y=test_predictions_inv,
    mode='lines',
    name='预测值',
    line=dict(color='#ff7f0e', dash='dot')
))

fig.update_layout(
    title=f'股票价格预测效果（最佳窗口：{best_window}天）',
    xaxis_title='日期',
    yaxis_title='收盘价（美元）',
    template='plotly_dark',
    hovermode='x unified'
)
fig.show()

# %%
# --- 性能指标计算 ---
mse = np.mean((true_values_inv - test_predictions_inv)**2)
print(f"\n测试集MSE: {mse:.4f}")
print(f"测试集RMSE: {np.sqrt(mse):.4f}")
print(f"测试集MAE: {np.mean(np.abs(true_values_inv - test_predictions_inv)):.4f}")
# Out:
# 测试集MSE: 9.3911
# 测试集RMSE: 3.0645
# 测试集MAE: 2.4147
